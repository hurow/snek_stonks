# %%
'''Udacity Course; ML for Finance'''


import os
import numpy as np
import pandas as pd
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader as web
import matplotlib.pyplot as plt
import datetime as dt

from matplotlib import style
from datetime import date

# %%
'''Read CSV Data'''
def test_run():
    """Function called by Test Run."""
    df = pd.read_csv("NCTY.csv")
    
    # TODO: Print last 5 rows of the data frame
    print(df.head(20))
if __name__ == "__main__":
    test_run()
# Out:
#           Date  Open  High   Low  Close  Adj Close  Volume
# 0   2018-05-24  1.22  1.25  1.14   1.15       1.15  122000
# 1   2018-05-25  1.22  1.22  1.17   1.18       1.18   27300
# 2   2018-05-29  1.17  1.20  1.11   1.11       1.11   48400
# 3   2018-05-30  1.13  1.17  1.11   1.14       1.14  144800
# 4   2018-05-31  1.14  1.14  1.11   1.12       1.12   62100
# 5   2018-06-01  1.12  1.14  1.05   1.07       1.07  138000
# 6   2018-06-04  1.07  1.09  1.02   1.06       1.06   66100
# 7   2018-06-05  1.06  1.07  1.02   1.03       1.03   72500
# 8   2018-06-06  1.03  1.28  1.02   1.26       1.26  423400
# 9   2018-06-07  1.30  1.38  1.18   1.24       1.24  744600
# 10  2018-06-08  1.22  1.22  1.10   1.10       1.10   89600
# 11  2018-06-11  1.08  1.20  1.08   1.13       1.13   71600
# 12  2018-06-12  1.18  1.18  1.08   1.10       1.10   42600
# 13  2018-06-13  1.09  1.15  1.08   1.11       1.11   46400
# 14  2018-06-14  1.10  1.12  1.06   1.09       1.09   23100
# ...

# %%
'''Slice Rows'''
def test_run():
    df= pd.read_csv("INNT.csv")
    print (df[0:22])
    
if __name__ == "__main__":
    test_run()
# Out:
#           Date   Open    High     Low  Close  Adj Close  Volume
# 0   2018-05-18  15.20  16.000  14.800  14.83      14.83  107600
# 1   2018-05-21  15.01  15.540  14.530  14.82      14.82   80800
# 2   2018-05-22  14.56  15.450  14.530  14.56      14.56   70300
# 3   2018-05-23  14.45  15.150  13.320  13.43      13.43  155900
# 4   2018-05-24  13.39  14.450  13.323  14.11      14.11   85000
# 5   2018-05-25  14.06  14.480  13.150  13.38      13.38   99600
# 6   2018-05-29  13.27  13.500  12.090  12.55      12.55  138100
# 7   2018-05-30  12.70  13.860  12.560  13.13      13.13   98400
# 8   2018-05-31  13.22  14.100  13.010  13.14      13.14  106500
# 9   2018-06-01  13.15  13.480  12.320  13.20      13.20  120500
# 10  2018-06-04  13.28  13.315  12.660  13.07      13.07   33900
# 11  2018-06-05  13.04  13.880  12.710  12.76      12.76   87700
# 12  2018-06-06  12.97  13.333  12.210  12.44      12.44  200300
# 13  2018-06-07  12.46  12.500  11.220  11.32      11.32  216800
# ...

# %%
'''Get max close'''
def get_max_close(symbol):
    df = pd.read_csv("{}.csv".format(symbol))
    return df['Close'].max()

def test_run():
    for symbol in ['INNT','OTLK']:
        print ('Max Close')
        print (symbol, get_max_close(symbol))

if __name__ == "__main__":
    test_run()
# Out:
# Max Close
# INNT 26.67
# Max Close
# OTLK 8.425

# %%
"""Compute mean volume"""


def get_mean_volume(symbol):
    """Return the mean volume for stock indicated by symbol.
    
    Note: Data for a stock is stored in file: data/<symbol>.csv
    """
    df = pd.read_csv("{}.csv".format(symbol))
    return df['Volume'].mean()
     
def test_run():
    """Function called by Test Run."""
    for symbol in ['INNT', 'OTLK']:
        print ("Mean Volume")
        print (symbol, get_mean_volume(symbol))


if __name__ == "__main__":
    test_run()
# Out:
# Mean Volume
# INNT 638531.8725099602
# Mean Volume
# OTLK 742774.3902439025

# %%
''' Plot High ##'''

def test_run():
    df = pd.read_csv('INNT.csv')
    high = df['High'].plot()
    plt.show()

if __name__ == "__main__":
    test_run()

# %%
'''Plot two columns 'Open', 'Close'''

import pandas as pd
import matplotlib.pyplot as plt

def test_run():
    df = pd.read_csv("INNT.csv")
    # TODO: Your code here
    df = df[-40:-20]
    print (df)
    df[["Close","Open"]].plot()
    plt.show()  # must be called to show plots


if __name__ == "__main__":
    test_run()
# Out:
#            Date   Open   High   Low  Close  Adj Close   Volume
# 211  2019-03-22  2.080  2.130  1.87   1.97       1.97   819600
# 212  2019-03-25  1.970  2.010  1.90   1.92       1.92   377800
# 213  2019-03-26  1.970  2.200  1.88   1.91       1.91  1737100
# 214  2019-03-27  1.920  1.950  1.78   1.80       1.80   666400
# 215  2019-03-28  1.810  1.866  1.70   1.73       1.73   557900
# 216  2019-03-29  1.740  1.960  1.61   1.93       1.93  1030200
# 217  2019-04-01  1.940  1.970  1.81   1.91       1.91   419400
# 218  2019-04-02  1.900  1.930  1.80   1.85       1.85   430900
# 219  2019-04-03  1.850  1.890  1.71   1.80       1.80   538200
# 220  2019-04-04  1.800  1.810  1.73   1.77       1.77   158900
# 221  2019-04-05  1.820  1.820  1.75   1.79       1.79   115900
# 222  2019-04-08  1.790  1.800  1.73   1.73       1.73   135600
# 223  2019-04-09  1.720  1.860  1.70   1.81       1.81   328800
# 224  2019-04-10  1.810  1.850  1.73   1.82       1.82   241500
# ...

# %%
'''Read in More Stocks; lesson 3-11'''
# def symbol_to_path(symbol):
#     #return CSV file path given ticker symbol
#     return os.path.join('{}.csv'.format(str(symbol))

                        
def test_run():  #error if symbol_to_path is uncommented!!! IDK y?
    #Define date range
    start_date='2018-04-18'
    end_date='2019-05-17'
    dates=pd.date_range(start_date, end_date)
    
    #Create an empty dataframe
    df1 = pd.DataFrame(index=dates)
    
    #Read SPY Data into temporary dataframe
    dfSPY = pd.read_csv('SPY.csv', index_col='Date',
                        parse_dates= True, usecols=['Date', 'High'],
                        na_values=['nan'])
    
    #Rename 'High' column to 'SPY' to prevent clash
    dfSPY = dfSPY.rename(columns={'High':'SPY'})
    
    #Join the two dataframes using DataFrame.join(), with how= 'inner'
    df1=df1.join(dfSPY, how='inner')
    
    #Read in more stocks
    
    symbols = ['INNT', 'OTLK', 'MBIO']
    for symbol in symbols:
#         df_temp=pd.read_csv('{}.csv'.format(symbol), index_col = 'Date', #non_modular version still works
#                             parse_dates = True, usecols=['Date','High'],
#                             na_values=['nan'])
        df_temp=pd.read_csv(symbol_to_path(symbol), index_col = 'Date',
                            parse_dates = True, usecols=['Date','High'],
                            na_values=['nan'])
        #Rename to prevent clash
        df_temp = df_temp.rename(columns={'High': symbol})
        df1=df1.join(df_temp)
    #print(df_temp)
    
    ax = df1.plot(title="Stock Prices")
    ax.set_xlabel('Date')
    ax.set_ylabel('Price')
    plt.show()

    print(df1)
if __name__ == "__main__":
    test_run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ceda2c1e5fb1> in <module>
#      47     print(df1)
#      48 if __name__ == "__main__":
# ---> 49     test_run()
#
# <ipython-input-8-ceda2c1e5fb1> in test_run()
#      32 #                             parse_dates = True, usecols=['Date','High'],
#      33 #                             na_values=['nan'])
# ---> 34         df_temp=pd.read_csv(symbol_to_path(symbol), index_col = 'Date',
#      35                             parse_dates = True, usecols=['Date','High'],
#      36                             na_values=['nan'])
#
# NameError: name 'symbol_to_path' is not defined

# %%
'''Plotting mulitple stocks'''

# def symbol_to_path(symbol):
#     #return CSV file path given ticker symbol
#     return os.path.join('{}.csv'.format(str(symbol))

                        
def test_run():  #error if symbol_to_path is uncommented!!! IDK y?
    #Define date range
    start_date='2018-04-18'
    end_date='2019-05-17'
    dates=pd.date_range(start_date, end_date)
    
    #Create an empty dataframe
    df1 = pd.DataFrame(index=dates)
    
    #Read SPY Data into temporary dataframe
    dfSPY = pd.read_csv('SPY.csv', index_col='Date',
                        parse_dates= True, usecols=['Date', 'High'],
                        na_values=['nan'])
    
    #Rename 'High' column to 'SPY' to prevent clash
    dfSPY = dfSPY.rename(columns={'High':'SPY'})
    
    #Join the two dataframes using DataFrame.join(), with how= 'inner'
    df1=df1.join(dfSPY, how='inner')
    
    #Read in more stocks
    
    symbols = ['INNT', 'OTLK', 'MBIO']
    for symbol in symbols:
#         df_temp=pd.read_csv('{}.csv'.format(symbol), index_col = 'Date', #non_modular version still works kinda
#                             parse_dates = True, usecols=['Date','High'],
#                             na_values=['nan'])
        df_temp=pd.read_csv(symbol_to_path(symbol), index_col = 'Date',
                            parse_dates = True, usecols=['Date','High'],
                            na_values=['nan'])
        #Rename to prevent clash
        df_temp = df_temp.rename(columns={'High': symbol})
        df1=df1.join(df_temp)
    #print(df_temp)
    
    ax = df1.plot(title="Stock Prices")
    ax.set_xlabel('Date')
    ax.set_ylabel('Price')
    plt.show()

if __name__ == "__main__":
    test_run()

# %%
# "Slice and plot two stocks"

# def plot_selected(df, columns, start_index, end_index):
#     plot_data(df.iloc[start_index:end_index, columns], title='Selected data')


# def symbol_to_path(symbol):
#     """Return CSV file path given ticker symbol."""
#     return os.path.join("{}.csv".format(str(symbol)))


# def get_data(symbols, dates):
#     """Read stock data (adjusted close) for given symbols from CSV files."""
#     df = pd.DataFrame(index=dates)
#     if 'SPY' not in symbols:  # add SPY for reference, if absent
#         symbols.insert(0, 'SPY')

#     for symbol in symbols:
#         df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
#                 parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
#         df_temp = df_temp.rename(columns={'Adj Close': symbol})
#         df = df.join(df_temp)
#         if symbol == 'SPY':  # drop dates SPY did not trade
#             df = df.dropna(subset=["SPY"])

#     return df


# def plot_data(df, title="Stock prices"):
#     """Plot stock prices with a custom title and meaningful axis labels."""
#     ax = df.plot(title=title, fontsize=12)
#     ax.set_xlabel("Date")
#     ax.set_ylabel("Price")
#     plt.show()


# def test_run():
#     # Define a date range
#     dates = pd.date_range('2018-05-17', '2019-05-16')

#     # Choose stock symbols to read
#     symbols = ['BLIN', 'INNT', 'MBIO']  # SPY will be added in get_data()
    
#     # Get stock data
#     df = get_data(symbols, dates)

#     # Slice and plot
#     plot_selected(df, ['BLIN', 'INNT'], '2018-05-20', '2019-05-10')


# if __name__ == "__main__":
#     test_run()

# %%
'''Normalizing data'''

# def symbol_to_path(symbol):
#     #return CSV file path given ticker symbol
#     return os.path.join('{}.csv'.format(str(symbol))

def normalize_data(df):
    return df/ df.iloc[0,:] #Normalize prices using first row of dataframe

                        
def test_run():  #error if symbol_to_path is uncommented!!! IDK y?
    #Define date range
    start_date='2018-04-18'
    end_date='2019-05-17'
    dates=pd.date_range(start_date, end_date)
    
    #Create an empty dataframe
    df1 = pd.DataFrame(index=dates)
    
    #Read SPY Data into temporary dataframe
    dfSPY = pd.read_csv('SPY.csv', index_col='Date',
                        parse_dates= True, usecols=['Date', 'High'],
                        na_values=['nan'])
    
    #Rename 'High' column to 'SPY' to prevent clash
    dfSPY = dfSPY.rename(columns={'High':'SPY'})
    
    #Join the two dataframes using DataFrame.join(), with how= 'inner'
    df1=df1.join(dfSPY, how='inner')
    
    #Read in more stocks
    
    symbols = ['INNT', 'OTLK', 'MBIO']
    for symbol in symbols:
        df_temp=pd.read_csv('{}.csv'.format(symbol), index_col = 'Date', #non_modular version still works kinda
                            parse_dates = True, usecols=['Date','High'],
                            na_values=['nan'])
#         df_temp=pd.read_csv(symbol_to_path(symbol), index_col = 'Date',
#                             parse_dates = True, usecols=['Date','High'],
#                             na_values=['nan'])
        #Rename to prevent clash
        df_temp = df_temp.rename(columns={'High': symbol})
        df1=df1.join(df_temp)
    
  
    #Normalize the data
    df1 =  normalize_data(df1)
    #Plot the Data
    ax = df1.plot(title="Stock Prices")
    ax.set_xlabel('Date')
    ax.set_ylabel('Price')
    plt.show()
    
    


if __name__ == "__main__":
    test_run()

# %%
# PRACTICE MODDING
# '''Normalizing data'''

# # def symbol_to_path(symbol):
# #     #return CSV file path given ticker symbol
# #     return os.path.join('{}.csv'.format(str(symbol))

# def normalize_data(df):
#     return df/ df.iloc[0,:] #Normalize prices using first row of dataframe

# def date_range(start_date, end_date):
#     #Define date range
#     dates=pd.date_range(start_date, end_date)
#     return dates

# def create_new_data_frame(dates):
#     df1 = pd.DataFrame(index=dates)
    
#     #Read SPY Data into temporary dataframe
#     dfSPY = pd.read_csv('SPY.csv', index_col='Date',
#                         parse_dates= True, usecols=['Date', 'High'],
#                         na_values=['nan'])
    
#     #Rename 'High' column to 'SPY' to prevent clash
#     dfSPY = dfSPY.rename(columns={'High':'SPY'})
    
#     #Join the two dataframes using DataFrame.join(), with how= 'inner'
#     df1=df1.join(dfSPY, how='inner')
    
#     return df1

# def test_run():  #error if symbol_to_path is uncommented!!! IDK y?
    
#     df1 = create_new_data_frame(date_range('2018-04-18','2019-05-17'))
    
#     #Read in more stocks# can you mod?
    
#     symbols = ['INNT', 'OTLK', 'MBIO']
#     for symbol in symbols:
#         df_temp=pd.read_csv(symbol_to_path(symbol), index_col = 'Date',
#                             parse_dates = True, usecols=['Date','High'],
#                             na_values=['nan'])
#         #Rename to prevent clash
#         df_temp = df_temp.rename(columns={'High': symbol})
#         df1=df1.join(df_temp)
   
#     #Normalize the data
#     df1 =  normalize_data(df1)
#     #Plot the Data
#     ax = df1.plot(title="Stock Prices")
#     ax.set_xlabel('Date')
#     ax.set_ylabel('Price')
#     plt.show()

# if __name__ == "__main__":
#     test_run()

# %%
# def symbol_read():
#     return pd.read_csv(os.path.join('{}.csv'.format(str(symbol)))) #check this code late

# symbols = ['INNT', 'SPY', 'OTLK']

# for symbol in symbols:
#     #Rename to prevent clash
#     symbol_read(symbols)
#     df_temp = df_temp.rename(columns={'High': symbol})
#     df1=df1.join(df_temp)


# print()

# %% [markdown]
# #Lesson 4: Numpy Power

# %%
'''Creating numpy arrays'''
def test_run():
    #list to 1D arrya
    print ('Array')
    print (np.array([2,3,4]))
    print ('empty')
    print (np.empty((3,9)))
    print ('ones')
    print (np.ones(((5),4)))
    print ('Random')
    print (np.random.random((5, 4)))
    print ('Normal')

if __name__ == '__main__':
    test_run()

# %%
'''Random integers'''
def test_run():
    print ('Random numbers with 0 as mean and s.d. of 1')
    print (np.random.normal(0,1,size=(3,3)))
    print ('Random intergers between 0 and 10')
    print (np.random.randint(0,30, size=(2,3)))

if __name__ == '__main__':
    test_run()

# %%
'''Shape/shape of arrays'''
def test_run():
    a = np.random.normal(0,1,size=(3,3))
    print (a)
    print (np.shape(a))
    print (len(a.shape)) #prints dimension of shape
    print (a.size)
    print (a.dtype)
if __name__ == '__main__':
    test_run()
# Out:
# [[ 0.4493488   0.23726307  0.03240397]
#  [-0.11053692  0.21410671  0.49670022]
#  [-1.50337063  0.40444885 -1.81599967]]
# (3, 3)
# 2
# 9
# float64

# %%
'''Operations on arrays'''
def test_run():
    np.random.seed(2)
    a = np.random.randint(0,10, size= (5,4))
    print ("Array:\n", a)
    
    #Sum of elements
    print("Sum of elements:\n",a.sum())
    #Iterate over rows, to compute the sum of each column
    print('Sum of each column \n', a.sum(axis=0))
    #Iterate over columns to compute the sum of each row
    print("Sum of each row\n",a.sum(axis=1))
if __name__ == '__main__':
    test_run()
# Out:
# Array:
#  [[8 8 6 2]
#  [8 7 2 1]
#  [5 4 4 5]
#  [7 3 6 4]
#  [3 7 6 1]]
# Sum of elements:
#  97
# Sum of each column
#  [31 29 24 13]
# Sum of each row
#  [24 18 18 20 17]

# %%
'''Operations on arrays/min,max'''

np.random.seed(2)
a = np.random.randint(0,10, size= (5,4))
print("Array:\n", a)
print("min of columns",a.min(axis=0))
print("max of columns",a.max(axis=1))
print('Mean of elements',a.mean())
# invalid syntax with spaces
print ('Mean of elements', a.mean()) #ok well this works but it is dicey
# Out:
# Array:
#  [[8 8 6 2]
#  [8 7 2 1]
#  [5 4 4 5]
#  [7 3 6 4]
#  [3 7 6 1]]
# min of columns [3 3 2 1]
# max of columns [8 8 5 7 7]
# Mean of elements 4.85
# Mean of elements 4.85

# %%
'''Argmax: getting index of Max'''

def get_max_index(a):
    """Return the index of the maximum value in given 1D array."""
    # TODO: Your code here
    return np.argmax(a)

def test_run():
    a = np.array([9, 6, 2, 3, 12, 14, 7, 10], dtype=np.int32)  # 32-bit integer array
    print("Array:", a)
    
    # Find the maximum and its index in array
    print("Maximum value:", a.max())
    print("Index of max:", get_max_index(a))


if __name__ == "__main__":
    test_run()
# Out:
# Array: [ 9  6  2  3 12 14  7 10]
# Maximum value: 14
# Index of max: 5

# %%
'''Using time function'''

import time

def test_run():
    t1 = time.time()
    print("ML4T")
    t2 = time.time()
    print("The time tken by print statement is",t2 - t1, "seconds.")
if __name__=="__main__":
    test_run()
# Out:
# ML4T
# The time tken by print statement is 0.00016808509826660156 seconds.

# %%
'''Accessing array elements'''

def test_run():
    a = np.random.rand(5,4)
    print("Array:\n",a)
    element = a[3,2]
    print("4th row 3rd column:", element)
    elements = a[0,1:3]
    print("Slice elements of 1st row:", elements)
    #Top-left corner ["rows", "elements in row"]
    print ("Top corner:\n",a[0:3,0:2])
    # slice columns [all rows, from columns 0 to 3 in steps of 2]
    print ("Columns 0 and 2:\n",a[:,0:3:2]) 
if __name__=="__main__":
    test_run()
# Out:
# Array:
#  [[0.49423684 0.84656149 0.07964548 0.50524609]
#  [0.0652865  0.42812233 0.09653092 0.12715997]
#  [0.59674531 0.226012   0.10694568 0.22030621]
#  [0.34982629 0.46778748 0.20174323 0.64040673]
#  [0.48306984 0.50523672 0.38689265 0.79363745]]
# 4th row 3rd column: 0.20174322626496533
# Slice elements of 1st row: [0.84656149 0.07964548]
# Top corner:
#  [[0.49423684 0.84656149]
#  [0.0652865  0.42812233]
#  [0.59674531 0.226012  ]]
# Columns 0 and 2:
#  [[0.49423684 0.07964548]
#  [0.0652865  0.09653092]
#  [0.59674531 0.10694568]
#  [0.34982629 0.20174323]
#  [0.48306984 0.38689265]]

# %%
'''Modifying elements'''

def test_run():
    a = np.random.rand(5,4)
    #assigning element
    a[0,0] = 1
    print("Change one element:\n",a)
    #assining row
    a[0,:] = 1
    print("Change whole row:\n",a)
    #assingning column
    b = [4,5,2,4,6]
    a[:,3] = b
    print("Assign values to a column :\n",a)
if __name__=="__main__":
    test_run()
# Out:
# Change one element:
#  [[1.         0.1622986  0.70075235 0.96455108]
#  [0.50000836 0.88952006 0.34161365 0.56714413]
#  [0.42754596 0.43674726 0.77655918 0.53560417]
#  [0.95374223 0.54420816 0.08209492 0.3663424 ]
#  [0.8508505  0.40627504 0.02720237 0.24717724]]
# Change whole row:
#  [[1.         1.         1.         1.        ]
#  [0.50000836 0.88952006 0.34161365 0.56714413]
#  [0.42754596 0.43674726 0.77655918 0.53560417]
#  [0.95374223 0.54420816 0.08209492 0.3663424 ]
#  [0.8508505  0.40627504 0.02720237 0.24717724]]
# Assign values to a column :
#  [[1.         1.         1.         4.        ]
#  [0.50000836 0.88952006 0.34161365 5.        ]
#  [0.42754596 0.43674726 0.77655918 2.        ]
#  [0.95374223 0.54420816 0.08209492 4.        ]
#  [0.8508505  0.40627504 0.02720237 6.        ]]

# %%
'''17.Indexing an array using another array'''

def test_run():
    a = np.random.rand(5)
    print (a)
    #accessing using list of slices
    indices = np.array([1,4,2,3])
    print (a[indices])
    
if __name__ == "__main__":
    test_run()
# Out:
# [0.06714437 0.99385201 0.97058031 0.80025835 0.60181712]
# [0.99385201 0.60181712 0.97058031 0.80025835]

# %%
''' boolean or "mask" index array'''

def test_run():
    a = np.array([(20,25,10,23,26,32,10,5,0),(0,2,50,20,0,1,28,5,0)])
    print (a)
    
    #calculating mean
    mean = a.mean()
    print (mean)
    
    #masking
    print (a[a<mean])
    
    #replace all values less than mean
    a[a<mean] = mean
    print(a)
    
if __name__ == "__main__":
    test_run()
# Out:
# [[20 25 10 23 26 32 10  5  0]
#  [ 0  2 50 20  0  1 28  5  0]]
# 14.277777777777779
# [10 10  5  0  0  2  0  1  5  0]
# [[20 25 14 23 26 32 14 14 14]
#  [14 14 50 20 14 14 28 14 14]]

# %%
''''''
# Out:
# ''

# %%
'''Arithmetic operations'''

import numpy as np

if __name__ == "__main__":
    test_run()

def test_run():
    a = np.array([(1,2,3,4,5), (10, 20,30,40,50)])
    print("Original array a:\n", a)
    
    #Multiply a by 2
    print ("\nMultiply a by 2:\n", 2.0 * a)
    
    #Divide a by 2
    print("\nDivide:\n",  a/2.0)

    b = np.array([(100,200,300,400,500), (1,2,3,4,5)])
    
    #Multiply a and b
    print ("\nMultiply a and b:\n", a * b)
# Out:
# [[20 25 10 23 26 32 10  5  0]
#  [ 0  2 50 20  0  1 28  5  0]]
# 14.277777777777779
# [10 10  5  0  0  2  0  1  5  0]
# [[20 25 14 23 26 32 14 14 14]
#  [14 14 50 20 14 14 28 14 14]]

# %%
##############################Lesson 5 Statistical Analysis ##########################

# %%
'''Lesson 5.5.Compute Global Statistics '''


'''Normalizing data'''

# def symbol_to_path(symbol):
#     #return CSV file path given ticker symbol
#     return os.path.join('{}.csv'.format(str(symbol))

def normalize_data(df):
    return df/ df.iloc[0,:] #Normalize prices using first row of dataframe

                        
def test_run():
    #error if symbol_to_path is uncommented!!! IDK y?
    #Define date range
    start_date='2018-04-18'
    end_date='2019-05-17'
    dates=pd.date_range(start_date, end_date)
    
    #Create an empty dataframe
    df1 = pd.DataFrame(index=dates)
    
    #Read SPY Data into temporary dataframe
    dfSPY = pd.read_csv('SPY.csv', index_col='Date',
                        parse_dates= True, usecols=['Date', 'High'],
                        na_values=['nan'])
    
    #Rename 'High' column to 'SPY' to prevent clash
    dfSPY = dfSPY.rename(columns={'High':'SPY'})
    
    #Join the two dataframes using DataFrame.join(), with how= 'inner'
    df1=df1.join(dfSPY, how='inner')
    
    #Read in more stocks
    
    symbols = ['INNT', 'OTLK', 'MBIO']
    for symbol in symbols:
        df_temp=pd.read_csv('{}.csv'.format(symbol), index_col = 'Date', #non_modular version still works kinda
                            parse_dates = True, usecols=['Date','High'],
                            na_values=['nan'])
#         df_temp=pd.read_csv(symbol_to_path(symbol), index_col = 'Date',
#                             parse_dates = True, usecols=['Date','High'],
#                             na_values=['nan'])
        #Rename to prevent clash
        df_temp = df_temp.rename(columns={'High': symbol})
        df1=df1.join(df_temp)
    
  
    #Normalize the data
    df1 =  normalize_data(df1)
    #Plot the Data
    ax = df1.plot(title="Stock Prices")
    ax.set_xlabel('Date')
    ax.set_ylabel('Price')
    plt.show()
################################Compute global statistics for each stock###############################
    print ('Median:\n',df1.median())
    print ('STD:\n',df1.std())


if __name__ == "__main__":
    test_run()
# Out:
# Median:
#  SPY     1.027203
# INNT    0.224375
# OTLK         NaN
# MBIO    0.596491
# dtype: float64
# STD:
#  SPY     0.039331
# INNT    0.356842
# OTLK         NaN
# MBIO    0.204360
# dtype: float64

# %%
'''Lesson 5.6: Rolling Stats'''
def test_run():  #error if symbol_to_path is uncommented!!! IDK y?
    #Define date range
    start_date='2018-05-24'
    end_date='2019-05-17'
    dates=pd.date_range(start_date, end_date)
    
    #Create an empty dataframe
    df1 = pd.DataFrame(index=dates)
    
    #Read SPY Data into temporary dataframe
    dfSPY = pd.read_csv('INNT.csv', index_col='Date',
                        parse_dates= True, usecols=['Date', 'High'],
                        na_values=['nan'])
    
    #Rename 'High' column to 'SPY' to prevent clash
    dfSPY = dfSPY.rename(columns={'High':'SPY'})
    
    #Join the two dataframes using DataFrame.join(), with how= 'inner'
    df1=df1.join(dfSPY, how='inner')
    
        #Normalize the data
    df1 =  normalize_data(df1)
    #Plot the Data
    ax = df1.plot(title="Stock Prices")
    ax.set_xlabel('Date')
    ax.set_ylabel('Price')
    #plt.show()
############################Lesson 5.6##############################
    #Plot SPY data, retain matplotlib axis object
    ax = df1.plot(title="Spy Rolling Mean", label='SPY')
    #Compute rolling mean using a 20 day window
    df1_Spy = df1['SPY']
    rm_SPY = df1_Spy.rolling(5).mean()
   
    #Add rolling mean to same plot
    rm_SPY.plot(label='20 day average:', ax=ax)
    ax.legend(loc='upper right')
    
    #Compute and plot std
    std_SPY = df1_Spy.std()
    print("std\n:",std_SPY)
#     std_SPY.plot(label='std', ax=ax)

if __name__ == "__main__":
    test_run()
# Out:
# std
# : 0.3889324197313138

# %%
'''Lesson 5.7: bolling bands'''
"""Bollinger Bands."""

import os
import pandas as pd
import matplotlib.pyplot as plt

def symbol_to_path(symbol):
    """Return CSV file path given ticker symbol."""
    return os.path.join("{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    """Read stock data (adjusted close) for given symbols from CSV files."""
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
                parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp)
        if symbol == 'SPY':  # drop dates SPY did not trade
            df = df.dropna(subset=["SPY"])

    return df


def plot_data(df, title="Stock prices"):
    """Plot stock prices with a custom title and meaningful axis labels."""
    ax = df.plot(title=title, fontsize=12)
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.show()

def get_rolling_mean(values, window):
    """Return rolling mean of given values, using specified window size."""
    return values.rolling(window).mean()

def get_rolling_std(values, window):
    """Return rolling standard deviation of given values, using specified window size."""
    # TODO: Compute and return rolling standard deviation
    return values.rolling(window).std()

def get_bollinger_bands(rm, rstd):
    """Return upper and lower Bollinger Bands."""
    # TODO: Compute upper_band and lower_band
    upper_band = rm + rstd * 2
    lower_band = rm - rstd * 2
    return upper_band, lower_band


def test_run():
    # Read data
    dates = pd.date_range('2019-01-24', '2019-05-24')
    symbols = ['NCTY']
    df = get_data(symbols, dates)

    # Compute Bollinger Bands
    # 1. Compute rolling mean
    rm_SPY = get_rolling_mean(df['NCTY'],3)

    # 2. Compute rolling standard deviation
    rstd_SPY = get_rolling_std(df['NCTY'],3)

    # 3. Compute upper and lower bands
    upper_band, lower_band = get_bollinger_bands(rm_SPY, rstd_SPY)

    # Plot raw SPY values, rolling mean and Bollinger Bands
    ax = df['NCTY'].plot(title="Bollinger Bands", label='NCTY')
    rm_SPY.plot(color='lightgrey',linestyle = 'dashed', label='Rolling mean', ax=ax)
    upper_band.plot(color='k',linestyle = 'dashed', label='upper band', ax=ax)
    lower_band.plot(color='grey',linestyle = 'dashed', label='lower band', ax=ax)
  
    # Add axis labels and legend
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    ax.legend(loc='upper left')
    plt.show()


if __name__ == "__main__":
    test_run()

# %%
"""5.10. Daily returns."""

import os
import pandas as pd
import matplotlib.pyplot as plt

def symbol_to_path(symbol):
    """Return CSV file path given ticker symbol."""
    return os.path.join("{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    """Read stock data (adjusted close) for given symbols from CSV files."""
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
                parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp)
        if symbol == 'SPY':  # drop dates SPY did not trade
            df = df.dropna(subset=["SPY"])

    return df


def plot_data(df, title="Stock prices", xlabel="Date", ylabel="Price"):
    """Plot stock prices with a custom title and meaningful axis labels."""
    ax = df.plot(title=title, fontsize=12)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.show()


def compute_daily_returns(df):
    """Compute and return the daily return values."""
    # TODO: Your code here
    # Note: Returned DataFrame must have the same number of rows
    daily_returns = df.copy() # copy given DataFrame to match size and column names
    #compute daily returns for row 1 onwards
    daily_returns[1:] = (df/df.shift(1)) - 1 #values divided by the following day, ty pandas!
    daily_returns.iloc[0, :] = 0 #Pandas leaves the 0th row full of NaNs
    return daily_returns

def test_run():
    # Read data
    dates = pd.date_range('2018-07-01', '2019-07-31')  # one month only
    symbols = ['SPY','OTLK']
    df = get_data(symbols, dates)
    plot_data(df)

    # Compute daily returns
    daily_returns = compute_daily_returns(df)
    plot_data(daily_returns, title="Daily returns", ylabel="Daily returns")


if __name__ == "__main__":
    test_run()

# %%
'''6.7 Computing histogram statistics'''
def test_run():
    # Read data
    dates = pd.date_range('2018-07-01', '2019-07-31')  # one month only
    symbols = ['SPY']
    df = get_data(symbols, dates)
    plot_data(df)

    # Compute daily returns
    daily_returns = compute_daily_returns(df)
    plot_data(daily_returns, title="Daily returns", ylabel="Daily returns")


if __name__ == "__main__":
    test_run()
